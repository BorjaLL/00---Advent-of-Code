# %% [markdown]
#  **word search** (your puzzle input). She only has to find one word: XMAS.
#
# This word search allows words to be horizontal, vertical, diagonal, written backwards, or even overlapping other words. It's a little unusual, though, as you don't merely need to find one instance of XMAS - you need to find all of them. Here are a few ways XMAS might appear, where irrelevant characters have been replaced with .:
#
# ```
# ..X...
# .SAMX.
# .A..A.
# XMAS.S
# .X....
# ```
#
# The actual word search will be full of letters instead. For example:
#
# ```
# MMMSXXMASM
# MSAMXMSMSA
# AMXSXMAAMM
# MSAMASMSMX
# XMASAMXAMM
# XXAMMXXAMA
# SMSMSASXSS
# SAXAMASAAA
# MAMMMXMMMM
# MXMXAXMASX
# ```
# In this word search, XMAS occurs a total of 18 times; here's the same word search again, but where letters not involved in any XMAS have been replaced with .:
#
# ```
# ....XXMAS.
# .SAMXMS...
# ...S..A...
# ..A.A.MS.X
# XMASAMX.MM
# X.....XA.A
# S.S.S.S.SS
# .A.A.A.A.A
# ..M.M.M.MM
# .X.X.XMASX
# ```
# Take a look at the little Elf's word search. **How many times does XMAS appear?**

# %%
def fInput(vtest): 
    test_input = '''MMMSXXMASM
MSAMXMSMSA
AMXSXMAAMM
MSAMASMSMX
XMASAMXAMM
XXAMMXXAMA
SMSMSASXSS
SAXAMASAAA
MAMMMXMMMM
MXMXAXMASX'''
    
    if vtest == 1:
        with open('/Users/bllanderas/Library/CloudStorage/OneDrive-Deloitte(O365D)/Documents/VSCODE/00---Advent-of-Code/2024/data/day4.txt', 'r') as f:
            test_input = f.read()

    import re
    input = re.split('\n' ,test_input)
    #input = test_input

    list1 = []
    for i in range (len(input)):
        #list1.append(i.split(' '))
        list1.append([])
        for j in input[i]:
            list1[i].append(j)

    return list1

# %%
def fSearchAround(vx,vy):
    vSol = 0
    vSol += fSearchRight(vx,vy)
    vSol += fSearchLeft(vx,vy)
    vSol += fSearchDown(vx,vy)
    vSol += fSearchUp(vx,vy)
    vSol += fSearchUL(vx,vy)
    vSol += fSearchUR(vx,vy)
    vSol += fSearchDL(vx,vy)
    vSol += fSearchDR(vx,vy)
    return vSol

def fSearchRight(vx,vy):
    if vx <= (len(input1[vy])-4):
        if input1[vy][vx+1] == 'M':
            if input1[vy][vx+2] == 'A':
                if input1[vy][vx+3] == 'S':
                    # print("right",vy,vx)
                    return 1

    return 0
def fSearchLeft(vx,vy):
    if vx >= (3):
        if input1[vy][vx-1] == 'M':
            if input1[vy][vx-2] == 'A':
                if input1[vy][vx-3] == 'S':
                    # print("left",vy,vx)
                    return 1

    return 0
def fSearchDown(vx,vy):
    if vy <= (len(input1)-4):
        if input1[vy+1][vx] == 'M':
            if input1[vy+2][vx] == 'A':
                if input1[vy+3][vx] == 'S':
                    # print("down",vy,vx)
                    return 1
    return 0
def fSearchUp(vx,vy):
    if vy >= (3):
        if input1[vy-1][vx] == 'M':
            if input1[vy-2][vx] == 'A':
                if input1[vy-3][vx] == 'S':
                    # print("up",vy,vx)
                    return 1
    return 0
def fSearchUL(vx,vy):
    if vy >= (3) and vx >= (3):
        if input1[vy-1][vx-1] == 'M':
            if input1[vy-2][vx-2] == 'A':
                if input1[vy-3][vx-3] == 'S':
                    # print("UL",vy,vx)
                    return 1
    return 0
def fSearchUR(vx,vy):
    if vy >= (3) and vx <= (len(input1[vy])-4):
        if input1[vy-1][vx+1] == 'M':
            if input1[vy-2][vx+2] == 'A':
                if input1[vy-3][vx+3] == 'S':
                    # print("UR",vy,vx)
                    return 1
    return 0
def fSearchDL(vx,vy):
    if vy <= (len(input1)-4) and vx >= (3):
        if input1[vy+1][vx-1] == 'M':
            if input1[vy+2][vx-2] == 'A':
                if input1[vy+3][vx-3] == 'S':
                    # print("DL",vy,vx)
                    return 1
    return 0
def fSearchDR(vx,vy):
    if vy <= (len(input1)-4) and vx <= (len(input1[vy])-4):
        if input1[vy+1][vx+1] == 'M':
            if input1[vy+2][vx+2] == 'A':
                if input1[vy+3][vx+3] == 'S':
                    # print("DR",vy,vx)
                    return 1
    return 0
input1=fInput(1)
sol1 = 0
for y in range(len(input1)):
    for x in range(len(input1[y])):
        if input1[y][x] == 'X':
            sol1 += fSearchAround(x,y)
            #print(sol1)
            

        #print (x,y)

input1
sol1
#right answer 2562
# Out:
# 2562

# %% [markdown]
# find two MAS in the shape of an X. One way to achieve that is like this:
# ```
# M.S
# .A.
# M.S
# ```
# Irrelevant characters have again been replaced with . in the above diagram. Within the X, each MAS can be written forwards or backwards.
#
# Here's the same example from before, but this time all of the X-MASes have been kept instead:
# ```
# .M.S......
# ..A..MSMS.
# .M.S.MAA..
# ..A.ASMSM.
# .M.S.M....
# ..........
# S.S.S.S.S.
# .A.A.A.A..
# M.M.M.M.M.
# ..........
# ```
# In this example, an X-MAS appears **9** times.
#
# Flip the word search from the instructions back over to the word search side and try again. **How many times does an X-MAS appear?**

# %%
def fSearchMas (vx,vy):
    vSol=0
    #UL MAS
    if input1[vy-1][vx-1] == 'M' and input1[vy+1][vx+1] == 'S':
        vSol += 1
    #UL SAM
    elif input1[vy-1][vx-1] == 'S' and input1[vy+1][vx+1] == 'M':
        vSol += 1
    
    #DL MAS
    if input1[vy+1][vx-1] == 'M' and input1[vy-1][vx+1] == 'S':
        vSol += 1
    #DL SAM
    elif input1[vy+1][vx-1] == 'S' and input1[vy-1][vx+1] == 'M':
        vSol += 1

    if vSol == 2:
        return 1
    return 0



input1=fInput(1)
sol2 = 0
for y in range(len(input1)):
    for x in range(len(input1[y])):
        if 1 <= y <= len(input1)-2 and 1 <= x <= len(input1[y])-2: 
            if input1[y][x] == 'A':
                sol2 += fSearchMas(x,y)
            #print(sol1)
            

        #print (x,y)

input1
sol2
#right answer 2562
# Out:
# 1902
