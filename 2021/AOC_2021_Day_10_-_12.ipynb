# %% [markdown]
# <a href="https://colab.research.google.com/github/BorjaLL/00---Advent-of-Code/blob/main/2021/AOC_2021_Day_10_-_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # day 10

# %%
test_input = """[({(<(())[]>[[{[]{<()<>>
[(()[<>])]({[<{<<[]>>(
{([(<{}[<>[]}>{[]{[(<()>
(((({<>}<{<{<>}{[]{[]{}
[[<[([]))<([[{}[[()]]]
[{[{({}]{}}([{[{{{}}([]
{<[[]]>}<{[{[{[]{()[[[]
[<(<(<(<{}))><([]([]()
<{([([[(<>()){}]>(<<{{
<{([{{}}[<[[[<>{}]]]>[]]"""
chunks = [i for i in test_input.split('\n')]

# %%
def checkLine (line):
  openers=[]
  for i in line:#range (0, len(line)):
    if i in ['(','[','{','<']:
      openers.append(i)
      #print (openers)
    else:
      if i == ')' and openers[-1] == '(':
        openers.pop(-1)
      elif i == ']' and openers[-1] == '[':
        openers.pop(-1)
      elif i == '}' and openers[-1] == '{':
        #print (i, openers[-1])
        openers.pop(-1)
      elif i == '>' and openers[-1] == '<':
        openers.pop(-1)
      else: 
        #print ("found ", i, "expected matching ", openers[-1])
        return i
    #print (openers)

def part1 (chunks):
  illegal = 0
  for i in chunks:
    char=checkLine(i)
    if char == ')':
      illegal += 3
    elif char == ']':
      illegal += 57
    elif char == '}':
      illegal += 1197
    elif char == '>':
      illegal += 25137
  print (illegal)
#checkLine('{([(<{}[<>[]}>{[]{[(<()>')
part1(chunks)
# Out:
# found  } expected matching  [
# found  ) expected matching  [
# found  ] expected matching  (
# found  ) expected matching  <
# found  > expected matching  [
# 26397

# %%
#@title
test_input = """[({<(({{(([([[{}{}](<>())][<(){}>[[][]]]){{(<>{})<{}()>}}](<<<()<>><()<>>>([<>[]])><{<[][]
<<([{([<([{<<{[]<>}([]{})>><{(<>{})([][])}[[{}]((){})]>}([[([]<>)[<><>)]{<{}[]>{[]()}}]<<[{}{}]<<>{}>>{[{}<>]
{<<[(<{<({[{[{[][]}{[]{}}](<[]<>>[<><>])}]}[<{(<<>{}>(()()))<(<>{})(<>())>}>{{{{()()}{<>}}}}])><<{{<{[
{({([<<<[<<<<[{}{}][<>]>[(<><>)]>[<{{}()}<[]<>>>]>>([{[[()<>]{[]<>}](([]{})[<>()])}(((())[{}])[{<>()}
[{[<[{[(([{({[()<>](<>())}[{<><>}[[]()]])((<{}[]><()[]>>[[<>{}]{<><>}])}<[<{{}[]}{()()}>{(
{<<{{[{{({{((([]()){{}()})){(<{}[]><()>)(<<>[]><[]<>>)}}[[[<()<>>][<()<>>(()())]]<[[[]<>]{
[{({[{[{[[<[<[<>{}]<[]>>{<<>[]><{}[]>}]>[[[[[]<>><<>{}>](<{}[]>[{}<>])]{<{<>{}}(<><>)><<{}[]>(<><>)>}]]<{{{{[
<<<{((({<<<[[[()<>]<[]()>](<{}()>)](({[]{}}<<>()>){{[]{}}})>{[[[{}[]]<{}{}>]{[[][]]{<>()}}]}><
({[<<{<({{[[(({}[])[<>()])<<{}[]>[[]<>]>]([{{}[]}<{}[]>]<{()[]}<{}()>>)]<[{<[]()>[{}{}]}{[()[]]}]<
([([[{[((<[[<[<><>][(){}]>[(()[])]]]<{<{[][]}([]())>([{}][<>{}])}<(<[][]>[(){}])(([][])<<>()>)>>><[
{<[<<([(([<([[{}[]](()())]<{<>()}>)[<(<>{})<<>{}>>{{[][])[()<>]}]>[[({<>{}}([]{})){[()()]}][{[<>]}(
([<[<[([([[[<<<>{}>><{()()}[{}[]]>]({<<>[]>{<>()}})](((<<>{}>{{}()}))<[([]<>){{}{}}]>)][{(
[[({(<[{<(([<{(){}}>)({<()[]><<>()>}<<()[]><<>>>))[{({(){}})(<{}<>>{[]<>})}[[([]())[()[]]]]])([<
[<<<{[({[<[<{[{}[]][[]<>]}>{<{{}<>}>({()[]}[{}[]])>]([<[{}()]<{}[]>>{[{}()]}]{[[(){}]{<>}]<<<
{[<[({((([(<{({}())}([{}[]]{<>[]})><[[[]{}](()())]{{<><>}{[]{}]}>)[[({<>()}<()()>)([()<>][()<>]
<<({({[[(<(<{[<>[]]({}{})}>)[<[{(){}}[{}[]]]<{<><>}>>]>{<(([()]<(){}>)([{}<>])){(<<>()>{[]()})(<{}{}>{{}{}
<{({(<<{[[{<{[<>()]{<>[]}}>}([{{<>[]}{[]()}}{{{}{}}{<>[]}}])]<<(((<>[]))<<[]()>[()()]>)<<<{}{}>>{<()<
{([{{[{<<<{<[{()()}{<>}][{[][]}{[][]}]>}<<[((){}){{}()}]{{(){}}{[]<>}}>[{<{}[]>}<{[][]}{{}[]
{{[((<[[[<{([<()[]>[()[]]]{[<><>][<><>]})([{()}][{<>[]}{{}[]}])}[[[<{}{}>({}{})]{<()<>>({}[])}]<
{(({[((<{(<{<<<>[]>{{}<>}>}(([(){}]<[]<>>))>[[(<<>>{<><>})(({}<>)(()<>))]])}>([<[(<[{}<>][[]<>]>[(
<{{[(<<{{(<({<<><>>({}())}[<[]()><<>[]>]){{(()()){<><>}}[({}{}){[]<>}]}>{(<<{}()><()()>>{{<>{}}{{}<>
{{<{({{{([{<({{}<>}{[][]}){{()[]}}><{{[]}{<>{}}}[{()<>}[<>[]]]>}[{([()]){({}<>)[<>{}])}(<<[][]>[()[]]>([
[{<(<({<<[[(<[[]{}]({}{})><<()<>>{[]()}>)({<[]()>([]())}{{[]{}}{<>[]}})]]{[(<{{}[]}{[][]}><[(){}]<<><>>>)]}>>
{<<(<({<{[<[{<()<>>}]<{[<><>]{[]{}}}<{<><>}>>>([[<[]()><{}()>]{{<>[]}>](<[<>{}]<[]{}>>[[()[]]{[]{}}])
<({<{<[{([<(({{}()}(<>()))([<><>]{[][]}))><<[<[][]>{()()}]>>]){[[({{[]}}{[()()]}){[(()[])[{}()]](([]<>){<><
[({{([<[({<((({}[])(<>()))<[<><>][{}{}]>)[[([]{})<<><>>]((<>{})([]{}))]>(([[[]()}{<><>}][{()[]}]){{<{}{
<{({[[{({((({([]<>){<>[]}}{{<><>}})(({()<>>[[]{}])<(()[])[[]{}]>)))})[{<<({[<>()]})([[()[]]<{}
[{<{[[<[<([((<{}<>><<><>>){<[]{}>[{}{}]})[[([])[[]()]]({<><>}<(){}>)]]{<((()[])([][])){(<>())([][])}>[{
<(([{<[<<[{<[[[][]]](<[]<>><<>[]>)>([{(){}}{{}[]}]{<<>[]><{}()>})}<{{([][])[{}<>]}{{{}()}}}[<(<
<<{((([<[(<[{<[]()>}{(())<()<>>}]>[{<[<>()]{()<>}>[{<><>}{[][]}]}{[<{}{}>({}<>)]{{[]()>{[]<>
[[[{[[[{{<(<{{[]<>}[<><>]}({()()}[()[]])>[((<>[])(<>)){{()<>}([][])}])[{{{[]<>}<()[])}({<>[]})}(({
{<<<(<(((({[[([])([][])]<<[]<>>>]}{{<{{}[]}(<>[])><{[][]}[[]{}]>}<{<()[]>}<{[]{}}{()<>}>>})){<<<[{[]<>}[[]"""
chunks = [i for i in test_input.split('\n')]

# %%
def checkLine (line):
  openers=[]
  for i in line:#range (0, len(line)):
    if i in ['(','[','{','<']:
      openers.append(i)
      #print (openers)
    else:
      if i == ')' and openers[-1] == '(':
        openers.pop(-1)
      elif i == ']' and openers[-1] == '[':
        openers.pop(-1)
      elif i == '}' and openers[-1] == '{':
        #print (i, openers[-1])
        openers.pop(-1)
      elif i == '>' and openers[-1] == '<':
        openers.pop(-1)
      else: 
        #print ("found ", i, "expected matching ", openers[-1])
        return i
    #print (openers)

def part1 (chunks):
  illegal = 0
  for i in chunks:
    char=checkLine(i)
    if char == ')':
      illegal += 3
    elif char == ']':
      illegal += 57
    elif char == '}':
      illegal += 1197
    elif char == '>':
      illegal += 25137
  print (illegal)
#checkLine('{([(<{}[<>[]}>{[]{[(<()>')
part1(chunks)
# Out:
# 436497

# %% [markdown]
# part 2

# %%
test_input = """[({(<(())[]>[[{[]{<()<>>
[(()[<>])]({[<{<<[]>>(
{([(<{}[<>[]}>{[]{[(<()>
(((({<>}<{<{<>}{[]{[]{}
[[<[([]))<([[{}[[()]]]
[{[{({}]{}}([{[{{{}}([]
{<[[]]>}<{[{[{[]{()[[[]
[<(<(<(<{}))><([]([]()
<{([([[(<>()){}]>(<<{{
<{([{{}}[<[[[<>{}]]]>[]]"""
chunks = [i for i in test_input.split('\n')]

# %%
def checkLine (line):
  openers=[]
  for i in line:#range (0, len(line)):
    if i in ['(','[','{','<']:
      openers.append(i)
      #print (openers)
    else:
      if i == ')' and openers[-1] == '(':
        openers.pop(-1)
      elif i == ']' and openers[-1] == '[':
        openers.pop(-1)
      elif i == '}' and openers[-1] == '{':
        #print (i, openers[-1])
        openers.pop(-1)
      elif i == '>' and openers[-1] == '<':
        openers.pop(-1)
      else: 
        #print ("found ", i, "expected matching ", openers[-1])
        #print("failed", line)
        return 0
  #print("success ", line)
  return openers
    #print (openers)
def completeLine (openers):
  #print (line, openers)
  ending =''
  for i in reversed(openers):
    if i == '(':
        openers.pop(-1)
        ending+=(')')
    elif i == '[':
        openers.pop(-1)
        ending+=(']')
    elif i == '{':
        openers.pop(-1)
        ending+=('}')
    elif i == '<':
        openers.pop(-1)
        ending+=('>')
  return calcSol(ending)
def calcSol(ending):
  total = 0
  for i in ending:
    if i == ')':
        total*= 5
        total+= 1
    elif i == ']':
        total*= 5
        total+= 2
    elif i == '}':
        total*= 5
        total+= 3
    elif i == '>':
        total*= 5
        total+= 4
  #print (total)
  return total
def part2 (chunks):
  sol = []
  for i in chunks:
    openers = checkLine(i)
    if openers != 0:
      sol.append(completeLine (openers))

    
  #print (sorted(sol))
  print (sorted(sol)[int((len(sol)-1)/2)])
#checkLine('{([(<{}[<>[]}>{[]{[(<()>')
part2(chunks)
#completeLine(['[', '(', '{', '(', '[', '[', '{', '{'])
#calcSol('}}>}>))))')
# Out:
# 2377613374

# %%
test=[294, 5566, 288957, 995444, 1480781]
(len(test)-1)/2
# Out:
# 2.0

# %% [markdown]
# # Day 11

# %%
test_input = """5483143223
2745854711
5264556173
6141336146
6357385478
4167524645
2176841721
6882881134
4846848554
5283751526"""
pulpos = [[[int(j),0] for j in i] for i in test_input.split('\n')]
smol_input = """11111
19991
19191
19991
11111"""
smol = [[[int(j),0] for j in i] for i in smol_input.split('\n')]
test1_input = """548
274
526"""
test1 = [[[int(j),0] for j in i] for i in test1_input.split('\n')]

# %%
def reset():
  global pulpos
  global smol
  global test1
  pulpos = [[[int(j),0] for j in i] for i in test_input.split('\n')]
  smol = [[[int(j),0] for j in i] for i in smol_input.split('\n')]
  test1 = [[[int(j),0] for j in i] for i in test1_input.split('\n')]
def step (pulpos): 
  for i in range (0, len(pulpos)):
    for j in range (0, len(pulpos[i])):
      if pulpos[i][j][0] < 10 : 
        pulpos[i][j][0] += 1
  #print ("after +1")
  #show(pulpos)
  for i in range (0, len(pulpos)):
    for j in range (0, len(pulpos[i])):
      if pulpos[i][j][0] ==  10 and pulpos[i][j][1] == 0:
        #print ("poppin ", i,j)
        pulpos[i][j][1] == 1
        pulpos = flash (i,j,pulpos)
  dim(pulpos)
  return pulpos
def flash(i,j,pulpos):
  #print (i,j,pulpos[i][j][0])
  #up
  if i > 0:
    if pulpos[i-1][j][0] <10:
      pulpos[i-1][j][0] += 1
      if pulpos[i-1][j][0] == 10 and pulpos[i-1][j][1] == 0:
        pulpos[i-1][j][1] = 1
        pulpos = flash (i-1,j,pulpos)
  #down
  if i < len (pulpos)-1:
    if pulpos[i+1][j][0] <10:
      pulpos[i+1][j][0] += 1
      if pulpos[i+1][j][0] == 10 and pulpos[i+1][j][1] == 0:
        pulpos[i+1][j][1] = 1
        pulpos = flash (i+1,j,pulpos)
  #left
  if j > 0:
    if pulpos[i][j-1][0] <10:
      pulpos[i][j-1][0] += 1
      if pulpos[i][j-1][0] == 10 and pulpos[i][j-1][1] == 0:
        pulpos[i][j-1][1] = 1
        pulpos = flash (i,j-1,pulpos)
  #right
  if j < len (pulpos [i])-1:
    if pulpos[i][j+1][0] <10:
      pulpos[i][j+1][0] += 1
      if pulpos[i][j+1][0] == 10 and pulpos[i][j+1][1] == 0:
        pulpos[i][j+1][1] = 1
        pulpos = flash (i,j+1,pulpos)
  #up left
  if i > 0 and j > 0:
    if pulpos[i-1][j-1][0] <10:
      pulpos[i-1][j-1][0] += 1
      if pulpos[i-1][j-1][0] == 10 and pulpos[i-1][j-1][1] == 0:
        pulpos[i-1][j-1][1] = 1
        pulpos = flash (i-1,j-1,pulpos)
  #up right
  if i > 0 and j < len (pulpos [i])-1:
    if pulpos[i-1][j+1][0] <10:
      pulpos[i-1][j+1][0] += 1
      if pulpos[i-1][j+1][0] == 10 and pulpos[i-1][j+1][1] == 0:
        pulpos[i-1][j+1][1] = 1
        pulpos = flash (i-1,j+1,pulpos)
  #down left
  if i < len (pulpos)-1 and j > 0:
    if pulpos[i+1][j-1][0] <10:
      pulpos[i+1][j-1][0] += 1
      if pulpos[i+1][j-1][0] == 10 and pulpos[i+1][j-1][1] == 0:
        pulpos[i+1][j-1][1] = 1
        pulpos = flash (i+1,j-1,pulpos)
  #down right
  if i < len (pulpos)-1 and j < len (pulpos [i])-1:
    if pulpos[i+1][j+1][0] <10:
      pulpos[i+1][j+1][0] += 1
      if pulpos[i+1][j+1][0] == 10and pulpos[i+1][j+1][1] == 0:
        pulpos[i+1][j+1][1] = 1
        pulpos = flash (i+1,j+1,pulpos)
  return pulpos

def dim (pulpos):
  global flashes
  for i in pulpos:
    for j in i:
      if j[0] == 10:
        flashes +=1
        j[0] = 0
        j[1] = 0

def cycle (times,pulpos):
  t = 0
  while t < times:
    #print ("#### cicle", t, "start")
    #show(pulpos)
    pulpos = step(pulpos)
    t += 1
  show(pulpos)
  print (flashes)

def show(pulpos):
  pmap = ''
  for i in pulpos:
    pmap += '\n'
    for j in i:
      pmap += str(j[0])
  print (pmap)
  #print (pulpos)

flashes = 0
reset()
cycle (100,pulpos)
#cycle (1,smol)
#cycle (2,smol)
#cycle (2,test1)
# Out:
# 0397666866
# 0749766918
# 0053976933
# 0004297822
# 0004229892
# 0053222877
# 0532222966
# 9322228966
# 7922286866
# 6789998766
# 1656

# %%
test_input = """2138862165
2726378448
3235172758
6281242643
4256223158
1112268142
1162836182
1543525861
1882656326
8844263151"""
pulpos = [[[int(j),0] for j in i] for i in test_input.split('\n')]

# %%
def reset():
  global pulpos
  global smol
  global test1
  pulpos = [[[int(j),0] for j in i] for i in test_input.split('\n')]
  smol = [[[int(j),0] for j in i] for i in smol_input.split('\n')]
  test1 = [[[int(j),0] for j in i] for i in test1_input.split('\n')]
def step (pulpos): 
  for i in range (0, len(pulpos)):
    for j in range (0, len(pulpos[i])):
      if pulpos[i][j][0] < 10 : 
        pulpos[i][j][0] += 1
  #print ("after +1")
  #show(pulpos)
  for i in range (0, len(pulpos)):
    for j in range (0, len(pulpos[i])):
      if pulpos[i][j][0] ==  10 and pulpos[i][j][1] == 0:
        #print ("poppin ", i,j)
        pulpos[i][j][1] == 1
        pulpos = flash (i,j,pulpos)
  dim(pulpos)
  return pulpos
def flash(i,j,pulpos):
  #print (i,j,pulpos[i][j][0])
  #up
  if i > 0:
    if pulpos[i-1][j][0] <10:
      pulpos[i-1][j][0] += 1
      if pulpos[i-1][j][0] == 10 and pulpos[i-1][j][1] == 0:
        pulpos[i-1][j][1] = 1
        pulpos = flash (i-1,j,pulpos)
  #down
  if i < len (pulpos)-1:
    if pulpos[i+1][j][0] <10:
      pulpos[i+1][j][0] += 1
      if pulpos[i+1][j][0] == 10 and pulpos[i+1][j][1] == 0:
        pulpos[i+1][j][1] = 1
        pulpos = flash (i+1,j,pulpos)
  #left
  if j > 0:
    if pulpos[i][j-1][0] <10:
      pulpos[i][j-1][0] += 1
      if pulpos[i][j-1][0] == 10 and pulpos[i][j-1][1] == 0:
        pulpos[i][j-1][1] = 1
        pulpos = flash (i,j-1,pulpos)
  #right
  if j < len (pulpos [i])-1:
    if pulpos[i][j+1][0] <10:
      pulpos[i][j+1][0] += 1
      if pulpos[i][j+1][0] == 10 and pulpos[i][j+1][1] == 0:
        pulpos[i][j+1][1] = 1
        pulpos = flash (i,j+1,pulpos)
  #up left
  if i > 0 and j > 0:
    if pulpos[i-1][j-1][0] <10:
      pulpos[i-1][j-1][0] += 1
      if pulpos[i-1][j-1][0] == 10 and pulpos[i-1][j-1][1] == 0:
        pulpos[i-1][j-1][1] = 1
        pulpos = flash (i-1,j-1,pulpos)
  #up right
  if i > 0 and j < len (pulpos [i])-1:
    if pulpos[i-1][j+1][0] <10:
      pulpos[i-1][j+1][0] += 1
      if pulpos[i-1][j+1][0] == 10 and pulpos[i-1][j+1][1] == 0:
        pulpos[i-1][j+1][1] = 1
        pulpos = flash (i-1,j+1,pulpos)
  #down left
  if i < len (pulpos)-1 and j > 0:
    if pulpos[i+1][j-1][0] <10:
      pulpos[i+1][j-1][0] += 1
      if pulpos[i+1][j-1][0] == 10 and pulpos[i+1][j-1][1] == 0:
        pulpos[i+1][j-1][1] = 1
        pulpos = flash (i+1,j-1,pulpos)
  #down right
  if i < len (pulpos)-1 and j < len (pulpos [i])-1:
    if pulpos[i+1][j+1][0] <10:
      pulpos[i+1][j+1][0] += 1
      if pulpos[i+1][j+1][0] == 10and pulpos[i+1][j+1][1] == 0:
        pulpos[i+1][j+1][1] = 1
        pulpos = flash (i+1,j+1,pulpos)
  return pulpos

def dim (pulpos):
  global flashes
  for i in pulpos:
    for j in i:
      if j[0] == 10:
        flashes +=1
        j[0] = 0
        j[1] = 0

def cycle (times,pulpos):
  t = 0
  while t < times:
    #print ("#### cicle", t, "start")
    #show(pulpos)
    pulpos = step(pulpos)
    t += 1
  show(pulpos)
  print (flashes)

def show(pulpos):
  pmap = ''
  for i in pulpos:
    pmap += '\n'
    for j in i:
      pmap += str(j[0])
  print (pmap)
  #print (pulpos)

flashes = 0
reset()
cycle (100,pulpos)
#cycle (1,smol)
#cycle (2,smol)
#cycle (2,test1)
# Out:
# 7932230000
# 9053234560
# 0043222233
# 0099222222
# 0966922233
# 0966995560
# 0099111300
# 0421111308
# 5211111297
# 3511111874
# 1735

# %% [markdown]
# part 2

# %%
test_input = """5483143223
2745854711
5264556173
6141336146
6357385478
4167524645
2176841721
6882881134
4846848554
5283751526"""
pulpos = [[[int(j),0] for j in i] for i in test_input.split('\n')]

# %%
test_input = """2138862165
2726378448
3235172758
6281242643
4256223158
1112268142
1162836182
1543525861
1882656326
8844263151"""
pulpos = [[[int(j),0] for j in i] for i in test_input.split('\n')]

# %%
def reset():
  global pulpos
  global smol
  global test1
  pulpos = [[[int(j),0] for j in i] for i in test_input.split('\n')]
  smol = [[[int(j),0] for j in i] for i in smol_input.split('\n')]
  test1 = [[[int(j),0] for j in i] for i in test1_input.split('\n')]
def step (pulpos): 
  for i in range (0, len(pulpos)):
    for j in range (0, len(pulpos[i])):
      if pulpos[i][j][0] < 10 : 
        pulpos[i][j][0] += 1
  #print ("after +1")
  #show(pulpos)
  for i in range (0, len(pulpos)):
    for j in range (0, len(pulpos[i])):
      if pulpos[i][j][0] ==  10 and pulpos[i][j][1] == 0:
        #print ("poppin ", i,j)
        pulpos[i][j][1] == 1
        pulpos = flash (i,j,pulpos)
  return pulpos
def flash(i,j,pulpos):
  #print (i,j,pulpos[i][j][0])
  #up
  if i > 0:
    if pulpos[i-1][j][0] <10:
      pulpos[i-1][j][0] += 1
      if pulpos[i-1][j][0] == 10 and pulpos[i-1][j][1] == 0:
        pulpos[i-1][j][1] = 1
        pulpos = flash (i-1,j,pulpos)
  #down
  if i < len (pulpos)-1:
    if pulpos[i+1][j][0] <10:
      pulpos[i+1][j][0] += 1
      if pulpos[i+1][j][0] == 10 and pulpos[i+1][j][1] == 0:
        pulpos[i+1][j][1] = 1
        pulpos = flash (i+1,j,pulpos)
  #left
  if j > 0:
    if pulpos[i][j-1][0] <10:
      pulpos[i][j-1][0] += 1
      if pulpos[i][j-1][0] == 10 and pulpos[i][j-1][1] == 0:
        pulpos[i][j-1][1] = 1
        pulpos = flash (i,j-1,pulpos)
  #right
  if j < len (pulpos [i])-1:
    if pulpos[i][j+1][0] <10:
      pulpos[i][j+1][0] += 1
      if pulpos[i][j+1][0] == 10 and pulpos[i][j+1][1] == 0:
        pulpos[i][j+1][1] = 1
        pulpos = flash (i,j+1,pulpos)
  #up left
  if i > 0 and j > 0:
    if pulpos[i-1][j-1][0] <10:
      pulpos[i-1][j-1][0] += 1
      if pulpos[i-1][j-1][0] == 10 and pulpos[i-1][j-1][1] == 0:
        pulpos[i-1][j-1][1] = 1
        pulpos = flash (i-1,j-1,pulpos)
  #up right
  if i > 0 and j < len (pulpos [i])-1:
    if pulpos[i-1][j+1][0] <10:
      pulpos[i-1][j+1][0] += 1
      if pulpos[i-1][j+1][0] == 10 and pulpos[i-1][j+1][1] == 0:
        pulpos[i-1][j+1][1] = 1
        pulpos = flash (i-1,j+1,pulpos)
  #down left
  if i < len (pulpos)-1 and j > 0:
    if pulpos[i+1][j-1][0] <10:
      pulpos[i+1][j-1][0] += 1
      if pulpos[i+1][j-1][0] == 10 and pulpos[i+1][j-1][1] == 0:
        pulpos[i+1][j-1][1] = 1
        pulpos = flash (i+1,j-1,pulpos)
  #down right
  if i < len (pulpos)-1 and j < len (pulpos [i])-1:
    if pulpos[i+1][j+1][0] <10:
      pulpos[i+1][j+1][0] += 1
      if pulpos[i+1][j+1][0] == 10and pulpos[i+1][j+1][1] == 0:
        pulpos[i+1][j+1][1] = 1
        pulpos = flash (i+1,j+1,pulpos)
  return pulpos

def dim (pulpos):
  global flashes
  boops = 0
  for i in pulpos:
    for j in i:
      if j[0] == 10:
        flashes +=1
        boops +=1
        j[0] = 0
        j[1] = 0
  if boops == 100:
    return 100

def cycle (times,pulpos):
  t = 0
  while t < times:
    #print ("#### cicle", t, "start")
    #show(pulpos)
    pulpos = step(pulpos)
    max = dim(pulpos)
    if max == 100:
      print ("NOW", t+1)
      show(pulpos)
      return
    t += 1
  show(pulpos)
  print (flashes)

def show(pulpos):
  pmap = ''
  for i in pulpos:
    pmap += '\n'
    for j in i:
      pmap += str(j[0])
  print (pmap)
  #print (pulpos)

flashes = 0
reset()
cycle (400,pulpos)
#cycle (1,smol)
#cycle (2,smol)
#cycle (2,test1)
# Out:
# NOW 400
#
# 0000000000
# 0000000000
# 0000000000
# 0000000000
# 0000000000
# 0000000000
# 0000000000
# 0000000000
# 0000000000
# 0000000000

# %% [markdown]
# # day 12

# %%
test_input ="""start-A
start-b
A-c
A-b
b-d
A-end
b-end"""

paths = [[j for j in i.split('-')] for i in test_input.split('\n')]
#print(paths)
#[['start', 'A'], ['start', 'b'], ['A', 'c'], ['A', 'b'], ['b', 'd'], ['A', 'end'], ['b', 'end']]
vpaths = dict()

for i,j in paths:
  if i.islower():
    vpaths.update({i:0})
  if j.islower():
    vpaths.update({j:0})
vpaths.pop('start')
vpaths.pop('end')
#print(vpaths)
#{'start': 0, 'b': 0, 'c': 0, 'd': 0, 'end': 0}
routes =[]
def travel(pos):
  global vpaths
  global paths
  global routes
  routes += [pos]
  if pos == 'end':
    return
  for i in paths:
    if i[0] == pos:
      if i[1] in vpaths:
        if vpaths[i[1]] >0:
          return
        vpaths[i[1]] += 1
      print (i[0], "to", i[1])
      travel(i[1])
    if i[1] == pos and i[0] != 'start':
      if i[0] in vpaths:
        if vpaths[i[0]] >0:
          return
        vpaths[i[0]] += 1
      print (i[1], "to", i[0])
      travel(i[0])




pos = 'start'

travel(pos)
print (routes)
# Out:
# start to A
# A to c
# c to A
# A to b
# b to A
# b to d
# b to end
# A to end
# ['start', 'A', 'c', 'A', 'b', 'A', 'd', 'end', 'end']

# %%
test_input ="""start-A
start-b
A-c
A-b
b-d
A-end
b-end"""

paths = [[j for j in i.split('-')] for i in test_input.split('\n')]
#print(paths)
#[['start', 'A'], ['start', 'b'], ['A', 'c'], ['A', 'b'], ['b', 'd'], ['A', 'end'], ['b', 'end']]
vpaths = dict()

for i,j in paths:
  if i.islower():
    vpaths.update({i:0})
  if j.islower():
    vpaths.update({j:0})
vpaths.pop('start')
vpaths.pop('end')
#print(vpaths)
#{'start': 0, 'b': 0, 'c': 0, 'd': 0, 'end': 0}
routes =[]

pos = 'start'

#start position
#looks where it can go
#checks if it can go there because lowercase can only be visited once
#records route
#shouldn't do the same route more than once


print (routes)

# %%
import networkx as nx

def visit(node='start', visited=set()):
    
    if node == 'end':
      return 1
    if node in visited:
      #print('bad')
      return 0
    v = visited.copy()
    if node.islower():
      v.add(node)
    sum = 0
    for child in caves[node]:
      #print(node,child)
      #print (v)
      sum += visit(child, v)
    return sum

with open('test.txt') as f:
    caves = nx.Graph([tuple(l.strip().split('-')) for l in f.readlines()])

print(visit())
# Out:
# {'start'}
# {'start'}
# {'start'}
# {'c', 'start'}
# {'c', 'start'}
# {'c', 'start'}
# {'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'd', 'start'}
# {'b', 'c', 'start'}
# {'c', 'start'}
# {'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'd', 'start'}
# {'b', 'start'}
# {'start'}
# {'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'c', 'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'start'}
# {'b', 'd', 'start'}
# {'b', 'start'}
# 10

# %% [markdown]
# part 2

# %%
import networkx as nx

def visit(node='start', visited=set(), double=False):
    if node == 'end':
        return 1
    if node in visited:
        if double:
            return 0
        else:
            if node == 'start':
                return 0
            double = True
    v = visited.copy()
    if node.islower():
        v.add(node)
    sum = 0
    for child in caves[node]:
        sum += visit(child, v, double)
    return sum

with open('input.txt') as f:
    caves = nx.Graph([tuple(l.strip().split('-')) for l in f.readlines()])

print(visit())
# Out:
# 96528
